# %%
import numpy as np
import copy

import random

import pad_discriminator_conformance #Our actual function

import statistics

from pm4py.objects.petri.importer import importer as pnml_importer

from pm4py.simulation.playout import simulator
from pm4py.objects.log.log import Trace, Event, EventLog

# %% [markdown]
# # Create artificial event log

# %%
trace1 = ['A', 'B', 'D', 'E', 'I']
trace2 = ['A', 'C', 'D', 'G', 'H', 'F', 'I']
trace3 = ['A', 'C', 'G', 'D', 'H', 'F', 'I']
trace4 = ['A', 'C', 'H', 'D', 'F', 'I']
trace5 = ['A', 'C', 'D', 'H', 'F', 'I']


traces = [trace1, trace2, trace3, trace4, trace5]
frequencies = [1207, 145, 56, 23, 28]

GT_log = []
for f in range(0, len(frequencies)):
    print(traces[f], frequencies[f])
    for i in range(0, frequencies[f]):
        GT_log.append(traces[f])
        
random.shuffle(GT_log)
# Out:
# ['A', 'B', 'D', 'E', 'I'] 1207
# ['A', 'C', 'D', 'G', 'H', 'F', 'I'] 145
# ['A', 'C', 'G', 'D', 'H', 'F', 'I'] 56
# ['A', 'C', 'H', 'D', 'F', 'I'] 23
# ['A', 'C', 'D', 'H', 'F', 'I'] 28

# %% [markdown]
# # Model log generation

# %%
def get_model_log(filename, num_traces):
    net, im , fm = pnml_importer.apply(filename) #import petri net
    #simulate model log
    loglist = simulator.apply(net, im, 
                        variant=simulator.Variants.BASIC_PLAYOUT, 
                        parameters={simulator.Variants.BASIC_PLAYOUT.value.Parameters.NO_TRACES: num_traces})
    #we want the log to be in a way Keras will accept it.
    log = []
    for i in range(len(loglist)):
        trace = []
        for j in range(len(loglist[i])):
            trace.append(loglist[i][j]['concept:name'].replace(" ", ""))
        log.append(trace)
    return(log)

# %% [markdown]
# # Tests

# %%
def test(GT_log, filename, times, modellogsize): 
    fitness_results1 = [] #we create lists because we want to calcukate the median of multiple runs
    precision_results1 = []
    fitness_results2 = []
    precision_results2 = []
    
    for i in range(0, times): #times is how much times you want to perform the experiment
        print(i+1, " OUT OF ", times)
        model_log = get_model_log(filename, modellogsize)
        #we each time get the avergae prob value or the count (with threshold 0.5)
        fitness1, fitness2 = pad_discriminator_conformance.get_distance(GT_log, model_log, "random") 
        precision1, precision2 = pad_discriminator_conformance.get_distance(model_log, GT_log, "random")
        fitness_results1.append(fitness1)
        fitness_results2.append(fitness2)
        precision_results1.append(precision1)
        precision_results2.append(precision2)
    #output median and standard error    
    print("FITNESS PROB VALUE:",statistics.median(fitness_results1), np.std(fitness_results1)/np.sqrt(times))
    print("FITNESS COUNT VALUE:",statistics.median(fitness_results2), np.std(fitness_results2)/np.sqrt(times))
    print("PREC PROB VALUE:", statistics.median(precision_results1),  np.std(precision_results1)/np.sqrt(times))
    print("PREC COUNT VALUE:", statistics.median(precision_results2),  np.std(precision_results2)/np.sqrt(times))

# %%
test(GT_log, "Model1.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  460 . Amount predicted true trace:  1040
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# FITNESS PROB VALUE: 0.9998378157615662 0.00011878633357019281
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.99940025806427 0.04290684038390888
# PREC COUNT VALUE: 1.0 0.02909295447354908

# %%
test(GT_log, "Model2.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  252 . Amount predicted true trace:  1207
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# FITNESS PROB VALUE: 0.8272567987442017 1.2290655918176221e-05
# FITNESS COUNT VALUE: 0.8272789581905414 0.0
# PREC PROB VALUE: 0.9998784065246582 3.332037088721049e-05
# PREC COUNT VALUE: 1.0 0.0

# %%
test(GT_log, "Model3.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1494 . Amount predicted true trace:  6
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1496 . Amount predicted true trace:  4
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1494 . Amount predicted true trace:  6
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1495 . Amount predicted true trace:  5
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1498 . Amount predicted true trace:  2
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1496 . Amount predicted true trace:  4
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1494 . Amount predicted true trace:  6
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1494 . Amount predicted true trace:  6
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1492 . Amount predicted true trace:  8
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1499 . Amount predicted true trace:  1
# fitness obtained
# FITNESS PROB VALUE: 0.7961235046386719 0.01225181040056413
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.004296585451811552 0.00046897582716102907
# PREC COUNT VALUE: 0.003666666666666667 0.00041952353926806064

# %%
test(GT_log, "Model4.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# FITNESS PROB VALUE: 0.9991921186447144 0.00047096156122177895
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.9982410669326782 0.00826648027969148
# PREC COUNT VALUE: 1.0 0.0

# %%
test(GT_log, "Model5.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  283 . Amount predicted true trace:  1217
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  50 . Amount predicted true trace:  1450
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  63 . Amount predicted true trace:  1437
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  89 . Amount predicted true trace:  1411
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  63 . Amount predicted true trace:  1437
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  221 . Amount predicted true trace:  1279
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  306 . Amount predicted true trace:  1194
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  278 . Amount predicted true trace:  1222
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  123 . Amount predicted true trace:  1377
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  263 . Amount predicted true trace:  1237
# fitness obtained
# FITNESS PROB VALUE: 0.9991894364356995 0.002054894593760072
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.9073723554611206 0.020586670025339024
# PREC COUNT VALUE: 0.8853333333333333 0.021091852033954295

# %%
test(GT_log, "Model6.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  512 . Amount predicted true trace:  988
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  280 . Amount predicted true trace:  1220
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  301 . Amount predicted true trace:  1199
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  375 . Amount predicted true trace:  1125
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  336 . Amount predicted true trace:  1164
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  441 . Amount predicted true trace:  1059
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  334 . Amount predicted true trace:  1166
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  332 . Amount predicted true trace:  1168
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  263 . Amount predicted true trace:  1237
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  463 . Amount predicted true trace:  1037
# fitness obtained
# FITNESS PROB VALUE: 0.999311625957489 9.677109936662505e-05
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.7698912024497986 0.013538096033878759
# PREC COUNT VALUE: 0.7766666666666666 0.01655805946762281

# %%
test(GT_log, "Model7.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  975 . Amount predicted true trace:  525
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  696 . Amount predicted true trace:  804
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1021 . Amount predicted true trace:  479
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  473 . Amount predicted true trace:  1027
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  404 . Amount predicted true trace:  1096
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  612 . Amount predicted true trace:  888
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  598 . Amount predicted true trace:  902
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  785 . Amount predicted true trace:  715
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  488 . Amount predicted true trace:  1012
# fitness obtained
# FITNESS PROB VALUE: 0.9981772899627686 0.0014052422213082076
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.5837041139602661 0.0429046445169223
# PREC COUNT VALUE: 0.5966666666666667 0.059189848979552415

# %%
test(GT_log, "Model8.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1495 . Amount predicted true trace:  5
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1494 . Amount predicted true trace:  6
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1459 . Amount predicted true trace:  0
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1499 . Amount predicted true trace:  1
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1496 . Amount predicted true trace:  4
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1314 . Amount predicted true trace:  145
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1483 . Amount predicted true trace:  17
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1408 . Amount predicted true trace:  51
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1494 . Amount predicted true trace:  6
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1491 . Amount predicted true trace:  9
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  196 . Amount predicted true trace:  1263
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1496 . Amount predicted true trace:  4
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  145 . Amount predicted true trace:  1314
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1497 . Amount predicted true trace:  3
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1314 . Amount predicted true trace:  145
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1488 . Amount predicted true trace:  12
# fitness obtained
# FITNESS PROB VALUE: 0.5166328549385071 0.020614485911222554
# FITNESS COUNT VALUE: 0.5191912268677176 0.13912528781336053
# PREC PROB VALUE: 0.0038816286250948906 0.0009391790986130022
# PREC COUNT VALUE: 0.003666666666666667 0.0009524238085595672

# %%
test(GT_log, "Model9.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  762 . Amount predicted true trace:  738
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  777 . Amount predicted true trace:  723
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  759 . Amount predicted true trace:  741
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  768 . Amount predicted true trace:  732
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  635 . Amount predicted true trace:  865
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  753 . Amount predicted true trace:  747
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  764 . Amount predicted true trace:  736
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  756 . Amount predicted true trace:  744
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  736 . Amount predicted true trace:  764
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  753 . Amount predicted true trace:  747
# fitness obtained
# FITNESS PROB VALUE: 0.9993305206298828 0.0011718441053806478
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.5045876502990723 0.009400979552659998
# PREC COUNT VALUE: 0.495 0.008113664742615111

# %%
test(GT_log, "Model10.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  201 . Amount predicted true trace:  1258
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1408 . Amount predicted true trace:  51
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1459 . Amount predicted true trace:  0
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  79 . Amount predicted true trace:  1380
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1459 . Amount predicted true trace:  0
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1459 . Amount predicted true trace:  0
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1459 . Amount predicted true trace:  0
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1500 . Amount predicted true trace:  0
# fitness obtained
# FITNESS PROB VALUE: 0.4285733997821808 0.10703876142221481
# FITNESS COUNT VALUE: 0.44859492803289924 0.15029467021360546
# PREC PROB VALUE: 2.8047563318978064e-05 7.599680744814691e-06
# PREC COUNT VALUE: 0.0 0.0

# %%
test(GT_log, "Model11.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1352 . Amount predicted true trace:  107
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1352 . Amount predicted true trace:  107
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1352 . Amount predicted true trace:  107
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1352 . Amount predicted true trace:  107
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# FITNESS PROB VALUE: 0.15010371804237366 0.013437128561944756
# FITNESS COUNT VALUE: 0.17272104180945852 0.015396369710762858
# PREC PROB VALUE: 0.9961004853248596 0.007835811154789435
# PREC COUNT VALUE: 1.0 0.0

# %%
test(GT_log, "Model_alpha_miner.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  371 . Amount predicted true trace:  1129
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  468 . Amount predicted true trace:  1032
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  379 . Amount predicted true trace:  1121
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  450 . Amount predicted true trace:  1050
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  457 . Amount predicted true trace:  1043
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  502 . Amount predicted true trace:  998
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  545 . Amount predicted true trace:  955
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  356 . Amount predicted true trace:  1144
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  368 . Amount predicted true trace:  1132
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  382 . Amount predicted true trace:  1118
# fitness obtained
# FITNESS PROB VALUE: 0.9642206430435181 0.0018473035842433165
# FITNESS COUNT VALUE: 0.9650445510623715 0.0
# PREC PROB VALUE: 0.7275315523147583 0.012931246280591757
# PREC COUNT VALUE: 0.7226666666666666 0.013104638703739816

# %%
test(GT_log, "Model_Inductiive_noise0.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  232 . Amount predicted true trace:  1268
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  226 . Amount predicted true trace:  1274
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  29 . Amount predicted true trace:  1471
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  492 . Amount predicted true trace:  1008
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  131 . Amount predicted true trace:  1369
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  704 . Amount predicted true trace:  796
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  109 . Amount predicted true trace:  1391
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  210 . Amount predicted true trace:  1290
# fitness obtained
# FITNESS PROB VALUE: 0.9995607137680054 0.00017141759085718532
# FITNESS COUNT VALUE: 1.0 0.0
# PREC PROB VALUE: 0.8630993366241455 0.04371793521795265
# PREC COUNT VALUE: 0.8863333333333333 0.04529381120344515

# %%
test(GT_log, "Model_Inductiive_noise0-5.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  190 . Amount predicted true trace:  1310
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  55 . Amount predicted true trace:  1445
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  390 . Amount predicted true trace:  1110
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  239 . Amount predicted true trace:  1261
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  259 . Amount predicted true trace:  1241
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  177 . Amount predicted true trace:  1323
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  251 . Amount predicted true trace:  1249
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  28 . Amount predicted true trace:  1431
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  579 . Amount predicted true trace:  921
# fitness obtained
# FITNESS PROB VALUE: 0.9981091022491455 0.002722530486580426
# FITNESS COUNT VALUE: 1.0 0.0036013891056680216
# PREC PROB VALUE: 0.8408927917480469 0.028052309133138612
# PREC COUNT VALUE: 0.857 0.035717284953428984

# %%
test(GT_log, "Model_Inductiive_noise1.pnml", 10, 1500)
# Out:
# 1  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1258 . Amount predicted true trace:  201
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  176 . Amount predicted true trace:  1324
# fitness obtained
# 2  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  745 . Amount predicted true trace:  755
# fitness obtained
# 3  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  51 . Amount predicted true trace:  1408
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  389 . Amount predicted true trace:  1111
# fitness obtained
# 4  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  562 . Amount predicted true trace:  938
# fitness obtained
# 5  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 6  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1258 . Amount predicted true trace:  201
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  754 . Amount predicted true trace:  746
# fitness obtained
# 7  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1230 . Amount predicted true trace:  229
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 8  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# 9  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  1207 . Amount predicted true trace:  252
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  762 . Amount predicted true trace:  738
# fitness obtained
# 10  OUT OF  10
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1459
# fitness obtained
# Random:
# Antilog obtained
# Fixed preprocessing
# training done
# Amount predicted antitrace:  0 . Amount predicted true trace:  1500
# fitness obtained
# FITNESS PROB VALUE: 0.181485116481781 0.10777319882248707
# FITNESS COUNT VALUE: 0.17272104180945852 0.12007165562114856
# PREC PROB VALUE: 0.817925214767456 0.05716418063322845
# PREC COUNT VALUE: 0.8116666666666668 0.06845831172651312
